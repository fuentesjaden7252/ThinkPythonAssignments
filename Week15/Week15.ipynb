# %% [markdown]
# <a href="https://colab.research.google.com/github/fuentesjaden7252/ThinkPythonAssignments/blob/main/Week15/Week15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
import os

TASKS_FILE = "tasks.json"
COMPLETED_FILE = "completed.json"

def load_tasks():
    if not os.path.exists(TASKS_FILE):
        return []
    with open(TASKS_FILE, "r") as f:
        return json.load(f)

def save_tasks(tasks):
    with open(TASKS_FILE, "w") as f:
        json.dump(tasks, f, indent=2)

def load_completed():
    if not os.path.exists(COMPLETED_FILE):
        return []
    with open(COMPLETED_FILE, "r") as f:
        return json.load(f)

def save_completed(completed_tasks):
    with open(COMPLETED_FILE, "w") as f:
        json.dump(completed_tasks, f, indent=2)

def add_task(tasks):
    name = input("Task name: ")
    priority = input("Priority (1=High, 2=Medium, 3=Low): ")

    task = {
        "name": name,
        "priority": int(priority)
    }

    tasks.append(task)
    print("Task added!")

def view_tasks(tasks):
    if not tasks:
        print("No tasks found.")
        return

    print("\nYour Tasks:")
    for i, t in enumerate(tasks):
        print(f"{i+1}. {t['name']} (Priority {t['priority']})")

def complete_task(tasks):
    if not tasks:
        print("No tasks to complete.")
        return

    view_tasks(tasks)
    index = int(input("Enter task number to complete: ")) - 1

    if 0 <= index < len(tasks):
        task = tasks.pop(index)

        completed = load_completed()
        completed.append(task)
        save_completed(completed)

        print(f"Completed: {task['name']}")
    else:
        print("Invalid task number.")

def what_is_next(tasks):
    priority_1_tasks = [t for t in tasks if t["priority"] == 1]

    if not priority_1_tasks:
        print("\n🎉 You're all caught up! No high-priority tasks right now.")
        return

    next_task = priority_1_tasks[0]

    print("\n👉 What you should do next:")
    print(f"{next_task['name']} (Priority 1)")

def main():
    tasks = load_tasks()

    while True:
        print("\n--- TASK MANAGER ---")
        print("1. Add Task")
        print("2. View Tasks")
        print("3. Complete Task")
        print("4. What is Next?")
        print("5. Exit")

        choice = input("Choose: ")

        if choice == "1":
            add_task(tasks)
            save_tasks(tasks)

        elif choice == "2":
            view_tasks(tasks)

        elif choice == "3":
            complete_task(tasks)
            save_tasks(tasks)

        elif choice == "4":
            what_is_next(tasks)

        elif choice == "5":
            save_tasks(tasks)
            break

        else:
            print("Invalid choice.")

if __name__ == "__main__":
    main()
# Out:
# --- TASK MANAGER ---
# 1. Add Task
# 2. View Tasks
# 3. Complete Task
# 4. What is Next?
# 5. Exit
# Choose: 1
# Task name: do homeowrk
# Priority (1=High, 2=Medium, 3=Low): 3
# Task added!
#
# --- TASK MANAGER ---
# 1. Add Task
# 2. View Tasks
# 3. Complete Task
# 4. What is Next?
# 5. Exit
# Choose: 2
#
# Your Tasks:
# 1. sleep (Priority 1)
# 2. sleep (Priority 1)
# 3. do homeowrk (Priority 3)
#
# --- TASK MANAGER ---
# 1. Add Task
# 2. View Tasks
# 3. Complete Task
# 4. What is Next?
# 5. Exit
# Choose: 3
#
# Your Tasks:
# 1. sleep (Priority 1)
# 2. sleep (Priority 1)
# 3. do homeowrk (Priority 3)
# Enter task number to complete: 2
# Completed: sleep
#
# --- TASK MANAGER ---
# 1. Add Task
# 2. View Tasks
# 3. Complete Task
# 4. What is Next?
# 5. Exit
# Choose: 4
#
# 👉 What you should do next:
# sleep (Priority 1)
#
# --- TASK MANAGER ---
# 1. Add Task
# 2. View Tasks
# 3. Complete Task
# 4. What is Next?
# 5. Exit
# Choose: 5
