# %% [markdown]
# <a href="https://colab.research.google.com/github/fuentesjaden7252/ThinkPythonAssignments/blob/main/Week9/Week9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# NAME: rentalcar.py
# IMPORT STATEMENTS
# None needed

# FUNCTION DEFINITIONS
# Define car classification

def classification_letter(name):
  if name == "B":
    return "Budget"
  if name == "S":
    return "Standard"
  if name == "L":
    return "Luxury"

def classification_cost(name):
  if name == "B":
    return 40
  if name == "S":
    return 60
  if name == "L":
    return 80

# Define mileage logic

def miles_amount(mileage):
  if mileage <= 100:
    return mileage -100
  else:
    return 0

# Define input validation
# Define total cost

def calculation_for_bill(days, mileage, name):

  daily_cost = classification_letter(name) * days
  mileas_cost = mileage * 0.35

  total = daily_cost + mileas_cost
  return total

# PROGRAM LOGIC

# Input validation

name = input("Enter classification code (B,S,L): ").upper()

while name != "B" and name != "S" and name != "L":
    print("Invalid classification code . Please enter B, S, or L.")
    name = input("Enter car classification (B, S, L): ").upper()

# Call functions to create questions

start_odometer = int(input("Enter starting odometer reading: "))
end_odometer = int(input("Enter ending odometer reading: "))
mileage = end_odometer - start_odometer
charged_miles = miles_amount(mileage)

# Final output
