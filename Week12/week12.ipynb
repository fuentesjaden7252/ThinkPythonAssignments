# %% [markdown]
# <a href="https://colab.research.google.com/github/fuentesjaden7252/ThinkPythonAssignments/blob/main/Week12/week12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# NAME: rectangle.py
# IMPORT STATEMENTS
# None

# FUNCTION DEFINITIONS
# def calculate_rectanlge
def calculate_rectangle(length, width):
# get length and width
    area = length * width
# calculate area and perimeter
    perimeter = 2 * (length + width)
# return results as tuple
    return (area, perimeter)

# PROGRAM LOGIC
# create input for length and width
length = float(input("Enter length: "))
width = float(input("Enter width: "))
# make results into single tuple
my_area, my_perimeter = calculate_rectangle(length, width)
# print final results
print("\n--- Results ---")
print("The Area is:", my_area)
print("The Perimeter is:", my_perimeter)
# Out:
# Enter length: 10
# Enter width: 5
#
# --- Results ---
# The Area is: 50.0
# The Perimeter is: 30.0
