# %% [markdown]
# <a href="https://colab.research.google.com/github/fuentesjaden7252/ThinkPythonAssignments/blob/main/week10/week10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# NAME: roster.py

# IMPORT STATEMENTS

# None

# FUNCTION DEFINITIONS

# Players added

# Players that are on roster

# PROGRAM LOGIC

# create and empty list

# call players added to fill roster

# ask for a name to search

# call players on roster

# print
# Out:
# Enter a palindrome: racecar
# Correct! You've pass the test.
