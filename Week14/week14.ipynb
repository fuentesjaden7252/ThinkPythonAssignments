# %% [markdown]
# <a href="https://colab.research.google.com/github/fuentesjaden7252/ThinkPythonAssignments/blob/main/Week14/week14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# NAME: library.py
# IMPORT STATEMENTS
# none

# CLASS DEFINITIONS

# class book
class Book:
# define "init" to accept title and author
    def __init__(self, title, author):
# set self.title = title
        self.title = title
# set self.author = author
        self.author = author
# set self.is_available = True
        self.is_available = True

# define "str"
# if book is available: return "Title by Author - Available"
# else: return "Title by Author - Checked Out"

# deinf "checkout"
# set self.is_available = False

# define "return_book"
# set self.is_available = True

# PROGRAM LOGIC

# create said books
book1 = Book("Think Python", "Allen Downey")
print(book1.title)
# print out status of books
# print checkout of book/books
# print the updated status of books
# Out:
# Think Python
