# %% [markdown]
# <a href="https://colab.research.google.com/github/fuentesjaden7252/ThinkPythonAssignments/blob/main/Week/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# (None)

# FUNCTION DEFINITIONS
# (None)

# PROGRAM LOGIC

# 1. Print the total numbers in a movie (2 * 68 + 45)
print( "Total minutes in movie: " + str(2 * 60 + 45) )

# 2. Print the years since 1947 (2026-1947)
print( "Years since first bug: " + str( 2026 - 1947 ) )

# 3. Print the total cost of 7 books (7 * 35)
print ( "Total cost of 7 books: " + str( 7 * 35) )
# Out:
# Total minutes in movie: 165
# Years since first bug: 79
# Total cost of 7 books: 245
