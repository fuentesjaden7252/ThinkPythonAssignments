# %% [markdown]
# <a href="https://colab.research.google.com/github/fuentesjaden7252/ThinkPythonAssignments/blob/main/Week7/Week7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# (None)

# FUNCTION DEFINITIONS
# 1. Define verify_pin():
#    - Create a loop that asks for a PIN until it equals "1234"
#    - Return True
def verify_pin():
  while True :
    pin = input("Enter PIN: ")
    if pin == "1234":
      print ("PIN verified")
      return True
    else:
      print("Incorrect PIN. Try again.")
# 2. Define withdraw(balance, amount):
#    - Check if enough money exists
#    - Return the new (or old) balance

# PROGRAM LOGIC
# 1. Set current_balance to 500
current_balance = 500
# 2. Call verify_pin()
verify_pin()

# 3. Get withdrawal amount from user input
# 4. Update current_balance by calling withdraw()
# 5. Print the final balance
# Out:
# Enter PIN: 600
# Incorrect PIN. Try again.
# Enter PIN: 2
# Incorrect PIN. Try again.
# Enter PIN: 1234
# PIN verified
# True
