# %% [markdown]
# <a href="https://colab.research.google.com/github/fuentesjaden7252/ThinkPythonAssignments/blob/main/Week4/Week4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# (None)

# FUNCTION DEFINITIONS
# 1. Define print_bio with three parameters: name, age, and goal.
# 2. Inside the function, use string multiplication (*) for a border line.
# 3. Print the bio details using the parameter names.
def print_bio(name, age, goal):
  print("*" * 25)
  print("Name:", name, "Age:", age, "Goal:", goal)
  print("*" * 25)
  print(" ")

# PROGRAM LOGIC
# 1. Call print_bio using my own info.
print_bio("Jaden,", "18", "Graduate College.")
# 2. Call print_bio using [Name of Famous Person].
print_bio("Luka Modric,", "40", "Play for the 2026 World Cup.")
# 3. Call print_bio using [Name of Fictional Character].
print_bio("Oswald,", "47", "Become the greatest wizard." )
# Out:
# *************************
# Name: Jaden, Age: 18 Goal: Graduate College.
# *************************
#
# *************************
# Name: Luka Modric, Age: 40 Goal: Play for the 2026 World Cup.
# *************************
#
# *************************
# Name: Oswald, Age: 47 Goal: Become the greatest wizard.
# *************************
